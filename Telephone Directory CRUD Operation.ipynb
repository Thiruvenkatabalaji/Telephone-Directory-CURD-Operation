# %%
import pymongo
mongo = pymongo.MongoClient("mongodb+srv://balaji:1234@cluster0.72kaxqn.mongodb.net/?retryWrites=true&w=majority")
db = mongo["Phone_Book"]
collection = db["Phone_contacts"]
collection

def create_contact():
    data = {
        "_id":input("Enter the name: "),
        "number":int(input("Enter the phone number: ")),
        "mail_id":input("Enter your mail_id")
    }
    data_1 = collection.insert_one(data)
    for data in collection.find():
        print(data);
    
    
def search_contact():
    y = input("Enter the name: ")
    query = ({"_id":y})
    for i in collection.find(query): # you can use this to retrive number or email ID{"number":True}
        print(i);
        
def delete_contact():
    z = input("Enter the contact name: ")
    query= ({"_id":z})
    y = collection.delete_one(query)
    print(z,"has been sucessfull deleted")
    for i in collection.find():
        print(i)
    
def pd_dataFrame():
    import pandas as pd
    collection_1= collection.find()
    collection_1 = pd.DataFrame(collection_1)
    print(collection_1)

def edit():
    print("Enter 1 to edit the Phone number: ");
    print("Enter 2 to edit the mail_id: ");
    n = int(input("Enter a number to edit : "));
    if 1<=n<=2:
        if n==1:
            c = int(input("Enter the existing Phone number : "));
            d = int(input("Enter the new Phone number:  "));
            query1 = ({"number":c});
            new_query1= {"$set":{"number":d}}
            z = collection.update_one(query1,new_query1);
            print("The update was successfull")
            for i in collection.find():
                print(i)
        if n==2:
            a = input("Enter the existing mail_id : ");
            b = input("Enter the new mail_id:  ");
            query = ({"mail_id":a});
            new_query= {"$set":{"mail_id":b}}
            collection.update_one(query,new_query);
            for i in collection.find():
                print(i)
        
    else:
        print("Retry \n Enter a valid number");
        
        

while True:
    print("\n--------Phone_Directory_Database---------");
    print("Enter 1 to create a contact")
    print("Enter 2 to search for a contact")
    print("Enter 3 to delete contact")
    print("Enter 4 to display all contact as Pandas DataFrame")
    print("Enter 5 to edit the contact details")
    print("Enter 6 to exit the operation")
    print("---------Waiting for operation-----------\n");


    n = int(input("Enter a number to perform operation: "))
    if (n<0) or (n<6):
        if n==1:
            create_contact();
            print("\n** The contact added successfully");
        elif n==2:
            search_contact();
        elif n==3:
            delete_contact();
        elif n==4:
            pd_dataFrame();
        elif n==5:
            edit();

    else:
        print("Exited")
        break;
